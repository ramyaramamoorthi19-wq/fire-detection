# %%
# Out:
# Found 32398 images belonging to 3 classes.
# Found 10500 images belonging to 3 classes.
# Epoch 1/5
# 1013/1013 ━━━━━━━━━━━━━━━━━━━━ 480s 473ms/step - accuracy: 0.8913 - loss: 0.3059 - val_accuracy: 0.8900 - val_loss: 0.3585
# Epoch 2/5
# 1013/1013 ━━━━━━━━━━━━━━━━━━━━ 522s 515ms/step - accuracy: 0.9282 - loss: 0.2189 - val_accuracy: 0.8977 - val_loss: 0.2681
# Epoch 3/5
# 1013/1013 ━━━━━━━━━━━━━━━━━━━━ 3339s 3s/step - accuracy: 0.9385 - loss: 0.1898 - val_accuracy: 0.9090 - val_loss: 0.2990
# Epoch 4/5
# 1013/1013 ━━━━━━━━━━━━━━━━━━━━ 705s 696ms/step - accuracy: 0.9432 - loss: 0.1757 - val_accuracy: 0.9378 - val_loss: 0.1713
# Epoch 5/5
# 1013/1013 ━━━━━━━━━━━━━━━━━━━━ 737s 727ms/step - accuracy: 0.9480 - loss: 0.1615 - val_accuracy: 0.9387 - val_loss: 0.1767
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model trained successfully!

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Image size
img_height, img_width = 224, 224
batch_size = 8

# Data preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    "C:\\Users\\ramam\\Downloads\\aiml\\train",
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'
)

test_data = test_datagen.flow_from_directory(
    'C:\\Users\\ramam\\Downloads\\aiml\\train',
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'
)

# Model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),

    Dense(128, activation='relu'),
    Dropout(0.5),

    Dense(1, activation='sigmoid')   # ✅ 2 class
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',      # ✅ change
    metrics=['accuracy']
) 

# Train
history = model.fit(
    train_data,
    validation_data=test_data,
    epochs=5  # 🔥 increase panniruken
)
          
# Save model
model.save("fire_detection.h5")

print("Training Completed ✅")
# Out:
# Found 23448 images belonging to 2 classes.
# Found 23448 images belonging to 2 classes.
# Epoch 1/5
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 1838s 626ms/step - accuracy: 0.9324 - loss: 0.2178 - val_accuracy: 0.9528 - val_loss: 0.1501
# Epoch 2/5
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 4708s 2s/step - accuracy: 0.9526 - loss: 0.1567 - val_accuracy: 0.9556 - val_loss: 0.1304
# Epoch 3/5
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 29984s 10s/step - accuracy: 0.9568 - loss: 0.1400 - val_accuracy: 0.9647 - val_loss: 0.1021
# Epoch 4/5
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 2320s 792ms/step - accuracy: 0.9618 - loss: 0.1264 - val_accuracy: 0.9382 - val_loss: 0.1870
# Epoch 5/5
# 2931/2931 ━━━━━━━━━━━━━━━━━━━━ 6314s 2s/step - accuracy: 0.9628 - loss: 0.1193 - val_accuracy: 0.9666 - val_loss: 0.1000
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Training Completed ✅
